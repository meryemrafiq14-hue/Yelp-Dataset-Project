# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
import pyodbc
import pandas as pd
import json

yelp_dataset = kagglehub.dataset_download('yelp-dataset/yelp-dataset')

#load business data
business_data = pd.read_json(f"{yelp_dataset}/yelp_academic_dataset_business.json", lines=True)

#load reviews data in chunks
reviews_chunks = pd.read_json(f"{yelp_dataset}/yelp_academic_dataset_review.json", lines=True, chunksize=10000) 

#store chunks in list of chunks
reviews_df_list = []
for chunk in reviews_chunks:
    reviews_df_list.append(chunk)

#combine to one df
reviews_df = pd.concat(reviews_df_list, ignore_index=True)

#load checkin data
checkin_chunks = pd.read_json(f"{yelp_dataset}/yelp_academic_dataset_checkin.json", lines=True, chunksize=10000)
checkin_df_list = []

for chunk in checkin_chunks:
    checkin_df_list.append(chunk)
#combine to one df
checkin_df = pd.concat(checkin_df_list, ignore_index=True)

print('Data source import complete.')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 6
#       1 # IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
#       2 # THEN FEEL FREE TO DELETE THIS CELL.
#       3 # NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
#       4 # ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
#       5 # NOTEBOOK.
# ----> 6 import kagglehub
#       7 import pyodbc
#       8 import pandas as pd
#
# ModuleNotFoundError: No module named 'kagglehub'

# %% [markdown]
# ### Flattening Business into 3 tables

# %%
def flatten_attributes(row):
    attributes = row.get('attributes', {})
    if attributes:
        attributes = json.loads(attributes) if isinstance(attributes, str) else attributes
        flattened = []
        for key, value in attributes.items():
            if key == 'RestaurantsPriceRange2':
                key = 'PriceRange'
            elif key == 'RestaurantsDelivery':
                key = 'Delivery'
            elif key == 'RestaurantsTakeOut':
                key = 'Takeout'
            flattened.append({'business_id': row['business_id'], 'attribute_key': key, 'attribute_value': value})
        return flattened
    return []

def flatten_hours(row):
    hours = row.get('hours', {})
    if hours:
        hours = json.loads(hours) if isinstance(hours, str) else hours
        flattened = []
        for day, time_range in hours.items():
            open_time, close_time = time_range.split('-')
            flattened.append({'business_id': row['business_id'], 'day': day, 'open_time': open_time, 'close_time': close_time})
        return flattened
    return []

# Flatten attributes and hours
attributes_data = []
hours_data = []

for _, row in business_data.iterrows():
    attributes_data.extend(flatten_attributes(row))
    hours_data.extend(flatten_hours(row))

# Convert to DataFrames
attributes_df = pd.DataFrame(attributes_data)
hours_df = pd.DataFrame(hours_data)

# Drop the original nested fields from the business table
business_flattened = business_data.drop(columns=['attributes', 'hours'])

# %% [markdown]
# ### Create Tables Queries

# %%
create_business_table = """
IF OBJECT_ID('dbo.business','U') IS NULL
CREATE TABLE business (
    business_id VARCHAR(22) PRIMARY KEY,
    name VARCHAR(255),
    address VARCHAR(255),
    city VARCHAR(100),
    state VARCHAR(10),
    postal_code VARCHAR(20),
    latitude FLOAT,
    longitude FLOAT,
    stars FLOAT,
    review_count INT,
    is_open BIT,
    categories TEXT
);
"""

create_attributes_table = """
IF OBJECT_ID('dbo.attributes','U') IS NULL
CREATE TABLE attributes (
    attribute_id INT IDENTITY(1,1) PRIMARY KEY,
    business_id VARCHAR(22),
    attribute_key VARCHAR(100),
    attribute_value VARCHAR(MAX),
    FOREIGN KEY (business_id) REFERENCES business(business_id)
);
"""

create_hours_table = """
IF OBJECT_ID('dbo.hours','U') IS NULL
CREATE TABLE hours (
    hour_id INT IDENTITY(1,1) PRIMARY KEY,
    business_id VARCHAR(22),
    day VARCHAR(20),
    open_time VARCHAR(20),
    close_time VARCHAR(20),
    FOREIGN KEY (business_id) REFERENCES business(business_id)
);
"""
create_review_table = """
IF OBJECT_ID('dbo.review','U') IS NULL
CREATE TABLE review (
    review_id VARCHAR(22) PRIMARY KEY,
    business_id VARCHAR(22),
    user_id VARCHAR(22),
    stars INT,
    date DATETIME,
    text TEXT,
    useful INT,
    funny INT,
    cool INT,
    FOREIGN KEY (business_id) REFERENCES business(business_id)
);
"""

create_checkin_table = """
IF OBJECT_ID('dbo.checkin','U') IS NULL
CREATE TABLE checkin (
    business_id VARCHAR(22) PRIMARY KEY,
    date TEXT,
    FOREIGN KEY (business_id) REFERENCES business(business_id)
);
"""

# %% [markdown]
# ### Database Information and connection

# %%
# Database connection configuration
# Set these as environment variables or update directly (not recommended for production)
import os

server = os.getenv('DB_SERVER', 'your-server.database.windows.net')
database = os.getenv('DB_NAME', 'your_database_name')
username = os.getenv('DB_USERNAME', 'your_username')
password = os.getenv('DB_PASSWORD', 'your_password')
driver = '{ODBC Driver 18 for SQL Server}'

# Connects to SQL Server
conn = pyodbc.connect(
    f'DRIVER={driver};SERVER={server};DATABASE={database};UID={username};PWD={password};'
    'Encrypt=yes;TrustServerCertificate=no;Connection Timeout=60;'
)
cursor = conn.cursor()
print("Connected.")
# Out:
# Connected.

# %% [markdown]
# ### Creates tables if not done already

# %%
#creates tables using queries above
cur = conn.cursor()
for sql in [
    create_business_table,
    create_attributes_table,
    create_hours_table,
    create_review_table,
    create_checkin_table,
]:
    cur.execute(sql)
conn.commit()
print("Tables created (or already existed).")
# Out:
# Tables created (or already existed).

# %% [markdown]
# ### Widening columns

# %%
#makes the table attributes large enough to contain the large text required
cur = conn.cursor()
ddl = [
    "ALTER TABLE business   ALTER COLUMN categories NVARCHAR(MAX) NULL;",
    "ALTER TABLE review     ALTER COLUMN text       NVARCHAR(MAX) NULL;",
    "ALTER TABLE checkin    ALTER COLUMN date       NVARCHAR(MAX) NULL;",
    "ALTER TABLE attributes ALTER COLUMN attribute_value NVARCHAR(MAX) NULL;",
]
for s in ddl:
    try:
        cur.execute(s)
        conn.commit()
    except Exception as e:
        print(s, "->", e)
print("DDL applied.")
# Out:
# DDL applied.

# %% [markdown]
# ### Upload Data in Chunks

# %%
# Cell: Philadelphia, PA filtered DataFrames (robust)

# Choose the business source (flattened if available)
business_src = business_flattened if 'business_flattened' in globals() else business_data

bd = business_src.copy()
bd["city_norm"] = bd["city"].astype(str).str.strip()
bd["state_norm"] = bd["state"].astype(str).str.strip().str.upper()

# Strict Philadelphia, PA filter
philadelphia_business_df = bd[
    (bd["city_norm"].str.lower() == "philadelphia") &
    (bd["state_norm"] == "PA")
].drop(columns=["city_norm","state_norm"], errors="ignore")

# If nothing found, print quick diagnostics
if len(philadelphia_business_df) == 0:
    print("No Philadelphia, PA businesses found. Diagnostics:")
    print("Unique states (sample):", bd["state_norm"].dropna().unique()[:10])
    print("Top cities in PA:")
    print(bd[bd["state_norm"] == "PA"]["city_norm"].value_counts().head(20))

philadelphia_bids = set(philadelphia_business_df["business_id"])

# Related tables filtered by business_id
philadelphia_attributes_df = attributes_df[attributes_df["business_id"].isin(philadelphia_bids)].copy()
philadelphia_hours_df = hours_df[hours_df["business_id"].isin(philadelphia_bids)].copy()
philadelphia_checkin_df = checkin_df[checkin_df["business_id"].isin(philadelphia_bids)].copy()

# Filter reviews by Philadelphia business_ids
philadelphia_reviews_df = reviews_df[reviews_df["business_id"].isin(philadelphia_bids)].copy()

# De-duplicate on natural keys
if len(philadelphia_attributes_df):
    philadelphia_attributes_df = (
        philadelphia_attributes_df.sort_values(["business_id","attribute_key"])
        .drop_duplicates(["business_id","attribute_key"], keep="last")
    )
if len(philadelphia_hours_df):
    philadelphia_hours_df = (
        philadelphia_hours_df.sort_values(["business_id","day"])
        .drop_duplicates(["business_id","day"], keep="last")
    )

print(f"Philadelphia, PA businesses: {len(philadelphia_business_df):,}")
print(f"Philadelphia, PA attributes: {len(philadelphia_attributes_df):,}")
print(f"Philadelphia, PA hours: {len(philadelphia_hours_df):,}")
print(f"Philadelphia, PA checkins: {len(philadelphia_checkin_df):,}")
print(f"Philadelphia, PA reviews: {len(philadelphia_reviews_df):,}")
# Out:
# Philadelphia, PA businesses: 14,575
# Philadelphia, PA attributes: 127,463
# Philadelphia, PA hours: 74,168
# Philadelphia, PA checkins: 12,899
# Philadelphia, PA reviews: 967,871

# %%
# Configurable batch size for Azure SQL (recommend 500–1000 on free tier)
BATCH_SIZE = 1000

def truncate_review_table(conn):
    """
    Empties the review table before uploading (faster than DELETE).
    Safe because no other table references review via FK.
    """
    cur = conn.cursor()
    cur.execute("TRUNCATE TABLE review;")
    conn.commit()
    print("Truncated table: review")

def upload_with_query(conn, df, insert_sql, param_order, batch_size=1000, table_name=""):
    """
    Generic batch uploader with progress logs.
    Converts NaN to None and uses fast_executemany for speed.
    """
    total = len(df)
    if total == 0:
        print(f"[{table_name}] Nothing to upload.")
        return
    cur = conn.cursor()
    cur.fast_executemany = True
    for start in range(0, total, batch_size):
        end = min(start + batch_size, total)
        part = df.iloc[start:end]
        part = part[param_order].astype(object)
        part = part.where(pd.notna(part), None)  # NaN -> None
        values = part.values.tolist()
        cur.executemany(insert_sql, values)
        conn.commit()
        print(f"[{table_name}] Uploaded {end}/{total} rows; remaining {total - end}.")

# MERGE/UPSERT for review on primary key review_id to avoid duplicates on retries
merge_review_sql = """
MERGE review AS tgt
USING (VALUES (?,?,?,?,?,?,?,?,?)) AS src (review_id,business_id,user_id,stars,[date],[text],useful,funny,cool)
ON tgt.review_id = src.review_id
WHEN MATCHED THEN
  UPDATE SET
    tgt.business_id = src.business_id,
    tgt.user_id     = src.user_id,
    tgt.stars       = src.stars,
    tgt.[date]      = src.[date],
    tgt.[text]      = src.[text],
    tgt.useful      = src.useful,
    tgt.funny       = src.funny,
    tgt.cool        = src.cool
WHEN NOT MATCHED THEN
  INSERT (review_id,business_id,user_id,stars,[date],[text],useful,funny,cool)
  VALUES (src.review_id,src.business_id,src.user_id,src.stars,src.[date],src.[text],src.useful,src.funny,src.cool);
"""

def upload_reviews_upsert(conn, df, batch_size=1000):
    """
    Batch UPSERT for reviews using MERGE to prevent duplicates.
    """
    total = len(df)
    if total == 0:
        print("[review] Nothing to upload.")
        return
    cur = conn.cursor()
    cur.fast_executemany = True
    for start in range(0, total, batch_size):
        end = min(start + batch_size, total)
        part = df.iloc[start:end]
        part = part[["review_id","business_id","user_id","stars","date","text","useful","funny","cool"]].astype(object)
        part = part.where(pd.notna(part), None)
        values = part.values.tolist()
        cur.executemany(merge_review_sql, values)  # executes per-row merge efficiently
        conn.commit()
        print(f"[review] Upserted {end}/{total} rows; remaining {total - end}.")

def upload_business_upsert(conn, df, batch_size=BATCH_SIZE):
    merge_sql = """
    MERGE business AS tgt
    USING (VALUES (?,?,?,?,?,?,?,?,?,?,?,?)) AS src
      (business_id,name,address,city,state,postal_code,latitude,longitude,stars,review_count,is_open,categories)
    ON tgt.business_id = src.business_id
    WHEN MATCHED THEN UPDATE SET
      name = src.name,
      address = src.address,
      city = src.city,
      state = src.state,
      postal_code = src.postal_code,
      latitude = src.latitude,
      longitude = src.longitude,
      stars = src.stars,
      review_count = src.review_count,
      is_open = src.is_open,
      categories = src.categories
    WHEN NOT MATCHED THEN
      INSERT (business_id,name,address,city,state,postal_code,latitude,longitude,stars,review_count,is_open,categories)
      VALUES (src.business_id,src.name,src.address,src.city,src.state,src.postal_code,src.latitude,src.longitude,src.stars,src.review_count,src.is_open,src.categories);
    """
    cols = ["business_id","name","address","city","state","postal_code","latitude","longitude","stars","review_count","is_open","categories"]
    total = len(df)
    if total == 0:
        print("[business] Nothing to upsert.")
        return
    cur = conn.cursor()
    cur.fast_executemany = True
    for start in range(0, total, batch_size):
        end = min(start + batch_size, total)
        part_df = df.iloc[start:end][cols]
        part = part_df.astype(object).where(pd.notna(part_df), None)
        cur.executemany(merge_sql, part.values.tolist())
        conn.commit()
        print(f"[business] Upserted {end}/{total}; remaining {total - end}.")

def upload_checkin_upsert(conn, df, batch_size=BATCH_SIZE):
    merge_sql = """
    MERGE checkin AS tgt
    USING (VALUES (?,?)) AS src (business_id,[date])
    ON tgt.business_id = src.business_id
    WHEN MATCHED THEN UPDATE SET [date] = src.[date]
    WHEN NOT MATCHED THEN INSERT (business_id,[date]) VALUES (src.business_id,src.[date]);
    """
    cols = ["business_id","date"]
    total = len(df)
    if total == 0:
        print("[checkin] Nothing to upsert.")
        return
    cur = conn.cursor()
    cur.fast_executemany = True
    for start in range(0, total, batch_size):
        end = min(start + batch_size, total)
        part_df = df.iloc[start:end][cols]
        part = part_df.astype(object).where(pd.notna(part_df), None)
        cur.executemany(merge_sql, part.values.tolist())
        conn.commit()
        print(f"[checkin] Upserted {end}/{total}; remaining {total - end}.")

def delete_rows_for_business_ids(conn, table, business_ids, batch_size=BATCH_SIZE):
    assert table in {"attributes", "hours"}, "Only attributes/hours deletion is allowed."
    ids = list(set(business_ids))
    total = len(ids)
    if total == 0:
        print(f"[{table}] No rows to delete.")
        return
    cur = conn.cursor()
    for start in range(0, total, batch_size):
        end = min(start + batch_size, total)
        chunk = ids[start:end]
        cur.executemany(f"DELETE FROM {table} WHERE business_id = ?", [(x,) for x in chunk])
        conn.commit()
        print(f"[{table}] Deleted for {end}/{total} business_ids; remaining {total - end}.")

business_insert_sql = """
INSERT INTO business (
  business_id, name, address, city, state, postal_code,
  latitude, longitude, stars, review_count, is_open, categories
) VALUES (?,?,?,?,?,?,?,?,?,?,?,?)
"""

attributes_insert_sql = "INSERT INTO attributes (business_id, attribute_key, attribute_value) VALUES (?,?,?)"
hours_insert_sql = "INSERT INTO hours (business_id, day, open_time, close_time) VALUES (?,?,?,?)"

# Bracket [date] and [text]
review_insert_sql = """
INSERT INTO review (
  review_id, business_id, user_id, stars, [date], [text], useful, funny, cool
) VALUES (?,?,?,?,?,?,?,?,?)
"""

# use business id as primary key
checkin_insert_sql = "INSERT INTO checkin (business_id, [date]) VALUES (?,?)"
checkin_params = ["business_id","date"]

# Param orders (column order for binding)
business_params = ["business_id","name","address","city","state","postal_code",
                   "latitude","longitude","stars","review_count","is_open","categories"]
attributes_params = ["business_id","attribute_key","attribute_value"]
hours_params = ["business_id","day","open_time","close_time"]
review_params = ["review_id","business_id","user_id","stars","date","text","useful","funny","cool"]
checkin_params = ["business_id","date"]

# %%
# Truncate review table before upload
truncate_review_table(conn)

# Upload (upsert) business and related filtered data
upload_business_upsert(conn, philadelphia_business_df, batch_size=BATCH_SIZE)
upload_checkin_upsert(conn, philadelphia_checkin_df, batch_size=BATCH_SIZE)
upload_with_query(conn, philadelphia_attributes_df, attributes_insert_sql, attributes_params, batch_size=BATCH_SIZE, table_name="attributes")
upload_with_query(conn, philadelphia_hours_df, hours_insert_sql, hours_params, batch_size=BATCH_SIZE, table_name="hours")
upload_reviews_upsert(conn, philadelphia_reviews_df, batch_size=BATCH_SIZE)

# Print sizes for verification
print(f"Philadelphia, PA businesses: {len(philadelphia_business_df):,}")
print(f"Philadelphia, PA attributes: {len(philadelphia_attributes_df):,}")
print(f"Philadelphia, PA hours: {len(philadelphia_hours_df):,}")
print(f"Philadelphia, PA checkins: {len(philadelphia_checkin_df):,}")
print(f"Philadelphia, PA reviews: {len(philadelphia_reviews_df):,}")
# Out:
# Truncated table: review
# [business] Upserted 1000/14575; remaining 13575.
# [business] Upserted 2000/14575; remaining 12575.
# [business] Upserted 3000/14575; remaining 11575.
# [business] Upserted 4000/14575; remaining 10575.
# [business] Upserted 5000/14575; remaining 9575.
# [business] Upserted 6000/14575; remaining 8575.
# [business] Upserted 7000/14575; remaining 7575.
# [business] Upserted 8000/14575; remaining 6575.
# [business] Upserted 9000/14575; remaining 5575.
# [business] Upserted 10000/14575; remaining 4575.
# [business] Upserted 11000/14575; remaining 3575.
# [business] Upserted 12000/14575; remaining 2575.
# [business] Upserted 13000/14575; remaining 1575.
# [business] Upserted 14000/14575; remaining 575.
# [business] Upserted 14575/14575; remaining 0.
# [checkin] Upserted 1000/12899; remaining 11899.
# [checkin] Upserted 2000/12899; remaining 10899.
# [checkin] Upserted 3000/12899; remaining 9899.
# [checkin] Upserted 4000/12899; remaining 8899.
# [checkin] Upserted 5000/12899; remaining 7899.
# [checkin] Upserted 6000/12899; remaining 6899.
# [checkin] Upserted 7000/12899; remaining 5899.
# [checkin] Upserted 8000/12899; remaining 4899.
# [checkin] Upserted 9000/12899; remaining 3899.
# [checkin] Upserted 10000/12899; remaining 2899.
# [checkin] Upserted 11000/12899; remaining 1899.
# [checkin] Upserted 12000/12899; remaining 899.
# [checkin] Upserted 12899/12899; remaining 0.
# [attributes] Uploaded 1000/127463 rows; remaining 126463.
# [attributes] Uploaded 2000/127463 rows; remaining 125463.
# [attributes] Uploaded 3000/127463 rows; remaining 124463.
# [attributes] Uploaded 4000/127463 rows; remaining 123463.
# [attributes] Uploaded 5000/127463 rows; remaining 122463.
# [attributes] Uploaded 6000/127463 rows; remaining 121463.
# [attributes] Uploaded 7000/127463 rows; remaining 120463.
# [attributes] Uploaded 8000/127463 rows; remaining 119463.
# [attributes] Uploaded 9000/127463 rows; remaining 118463.
# [attributes] Uploaded 10000/127463 rows; remaining 117463.
# [attributes] Uploaded 11000/127463 rows; remaining 116463.
# [attributes] Uploaded 12000/127463 rows; remaining 115463.
# [attributes] Uploaded 13000/127463 rows; remaining 114463.
# [attributes] Uploaded 14000/127463 rows; remaining 113463.
# [attributes] Uploaded 15000/127463 rows; remaining 112463.
# [attributes] Uploaded 16000/127463 rows; remaining 111463.
# [attributes] Uploaded 17000/127463 rows; remaining 110463.
# [attributes] Uploaded 18000/127463 rows; remaining 109463.
# [attributes] Uploaded 19000/127463 rows; remaining 108463.
# [attributes] Uploaded 20000/127463 rows; remaining 107463.
# [attributes] Uploaded 21000/127463 rows; remaining 106463.
# [attributes] Uploaded 22000/127463 rows; remaining 105463.
# [attributes] Uploaded 23000/127463 rows; remaining 104463.
# [attributes] Uploaded 24000/127463 rows; remaining 103463.
# [attributes] Uploaded 25000/127463 rows; remaining 102463.
# [attributes] Uploaded 26000/127463 rows; remaining 101463.
# [attributes] Uploaded 27000/127463 rows; remaining 100463.
# [attributes] Uploaded 28000/127463 rows; remaining 99463.
# [attributes] Uploaded 29000/127463 rows; remaining 98463.
# [attributes] Uploaded 30000/127463 rows; remaining 97463.
# [attributes] Uploaded 31000/127463 rows; remaining 96463.
# [attributes] Uploaded 32000/127463 rows; remaining 95463.
# [attributes] Uploaded 33000/127463 rows; remaining 94463.
# [attributes] Uploaded 34000/127463 rows; remaining 93463.
# [attributes] Uploaded 35000/127463 rows; remaining 92463.
# [attributes] Uploaded 36000/127463 rows; remaining 91463.
# [attributes] Uploaded 37000/127463 rows; remaining 90463.
# [attributes] Uploaded 38000/127463 rows; remaining 89463.
# [attributes] Uploaded 39000/127463 rows; remaining 88463.
# [attributes] Uploaded 40000/127463 rows; remaining 87463.
# [attributes] Uploaded 41000/127463 rows; remaining 86463.
# [attributes] Uploaded 42000/127463 rows; remaining 85463.
# [attributes] Uploaded 43000/127463 rows; remaining 84463.
# [attributes] Uploaded 44000/127463 rows; remaining 83463.
# [attributes] Uploaded 45000/127463 rows; remaining 82463.
# [attributes] Uploaded 46000/127463 rows; remaining 81463.
# [attributes] Uploaded 47000/127463 rows; remaining 80463.
# [attributes] Uploaded 48000/127463 rows; remaining 79463.
# [attributes] Uploaded 49000/127463 rows; remaining 78463.
# [attributes] Uploaded 50000/127463 rows; remaining 77463.
# [attributes] Uploaded 51000/127463 rows; remaining 76463.
# [attributes] Uploaded 52000/127463 rows; remaining 75463.
# [attributes] Uploaded 53000/127463 rows; remaining 74463.
# [attributes] Uploaded 54000/127463 rows; remaining 73463.
# [attributes] Uploaded 55000/127463 rows; remaining 72463.
# [attributes] Uploaded 56000/127463 rows; remaining 71463.
# [attributes] Uploaded 57000/127463 rows; remaining 70463.
# [attributes] Uploaded 58000/127463 rows; remaining 69463.
# [attributes] Uploaded 59000/127463 rows; remaining 68463.
# [attributes] Uploaded 60000/127463 rows; remaining 67463.
# [attributes] Uploaded 61000/127463 rows; remaining 66463.
# [attributes] Uploaded 62000/127463 rows; remaining 65463.
# [attributes] Uploaded 63000/127463 rows; remaining 64463.
# [attributes] Uploaded 64000/127463 rows; remaining 63463.
# [attributes] Uploaded 65000/127463 rows; remaining 62463.
# [attributes] Uploaded 66000/127463 rows; remaining 61463.
# [attributes] Uploaded 67000/127463 rows; remaining 60463.
# [attributes] Uploaded 68000/127463 rows; remaining 59463.
# [attributes] Uploaded 69000/127463 rows; remaining 58463.
# [attributes] Uploaded 70000/127463 rows; remaining 57463.
# [attributes] Uploaded 71000/127463 rows; remaining 56463.
# [attributes] Uploaded 72000/127463 rows; remaining 55463.
# [attributes] Uploaded 73000/127463 rows; remaining 54463.
# [attributes] Uploaded 74000/127463 rows; remaining 53463.
# [attributes] Uploaded 75000/127463 rows; remaining 52463.
# [attributes] Uploaded 76000/127463 rows; remaining 51463.
# [attributes] Uploaded 77000/127463 rows; remaining 50463.
# [attributes] Uploaded 78000/127463 rows; remaining 49463.
# [attributes] Uploaded 79000/127463 rows; remaining 48463.
# [attributes] Uploaded 80000/127463 rows; remaining 47463.
# [attributes] Uploaded 81000/127463 rows; remaining 46463.
# [attributes] Uploaded 82000/127463 rows; remaining 45463.
# [attributes] Uploaded 83000/127463 rows; remaining 44463.
# [attributes] Uploaded 84000/127463 rows; remaining 43463.
# [attributes] Uploaded 85000/127463 rows; remaining 42463.
# [attributes] Uploaded 86000/127463 rows; remaining 41463.
# [attributes] Uploaded 87000/127463 rows; remaining 40463.
# [attributes] Uploaded 88000/127463 rows; remaining 39463.
# [attributes] Uploaded 89000/127463 rows; remaining 38463.
# [attributes] Uploaded 90000/127463 rows; remaining 37463.
# [attributes] Uploaded 91000/127463 rows; remaining 36463.
# [attributes] Uploaded 92000/127463 rows; remaining 35463.
# [attributes] Uploaded 93000/127463 rows; remaining 34463.
# [attributes] Uploaded 94000/127463 rows; remaining 33463.
# [attributes] Uploaded 95000/127463 rows; remaining 32463.
# [attributes] Uploaded 96000/127463 rows; remaining 31463.
# [attributes] Uploaded 97000/127463 rows; remaining 30463.
# [attributes] Uploaded 98000/127463 rows; remaining 29463.
# [attributes] Uploaded 99000/127463 rows; remaining 28463.
# [attributes] Uploaded 100000/127463 rows; remaining 27463.
# [attributes] Uploaded 101000/127463 rows; remaining 26463.
# [attributes] Uploaded 102000/127463 rows; remaining 25463.
# [attributes] Uploaded 103000/127463 rows; remaining 24463.
# [attributes] Uploaded 104000/127463 rows; remaining 23463.
# [attributes] Uploaded 105000/127463 rows; remaining 22463.
# [attributes] Uploaded 106000/127463 rows; remaining 21463.
# [attributes] Uploaded 107000/127463 rows; remaining 20463.
# [attributes] Uploaded 108000/127463 rows; remaining 19463.
# [attributes] Uploaded 109000/127463 rows; remaining 18463.
# [attributes] Uploaded 110000/127463 rows; remaining 17463.
# [attributes] Uploaded 111000/127463 rows; remaining 16463.
# [attributes] Uploaded 112000/127463 rows; remaining 15463.
# [attributes] Uploaded 113000/127463 rows; remaining 14463.
# [attributes] Uploaded 114000/127463 rows; remaining 13463.
# [attributes] Uploaded 115000/127463 rows; remaining 12463.
# [attributes] Uploaded 116000/127463 rows; remaining 11463.
# [attributes] Uploaded 117000/127463 rows; remaining 10463.
# [attributes] Uploaded 118000/127463 rows; remaining 9463.
# [attributes] Uploaded 119000/127463 rows; remaining 8463.
# [attributes] Uploaded 120000/127463 rows; remaining 7463.
# [attributes] Uploaded 121000/127463 rows; remaining 6463.
# [attributes] Uploaded 122000/127463 rows; remaining 5463.
# [attributes] Uploaded 123000/127463 rows; remaining 4463.
# [attributes] Uploaded 124000/127463 rows; remaining 3463.
# [attributes] Uploaded 125000/127463 rows; remaining 2463.
# [attributes] Uploaded 126000/127463 rows; remaining 1463.
# [attributes] Uploaded 127000/127463 rows; remaining 463.
# [attributes] Uploaded 127463/127463 rows; remaining 0.
# [hours] Uploaded 1000/74168 rows; remaining 73168.
# [hours] Uploaded 2000/74168 rows; remaining 72168.
# [hours] Uploaded 3000/74168 rows; remaining 71168.
# [hours] Uploaded 4000/74168 rows; remaining 70168.
# [hours] Uploaded 5000/74168 rows; remaining 69168.
# [hours] Uploaded 6000/74168 rows; remaining 68168.
# [hours] Uploaded 7000/74168 rows; remaining 67168.
# [hours] Uploaded 8000/74168 rows; remaining 66168.
# [hours] Uploaded 9000/74168 rows; remaining 65168.
# [hours] Uploaded 10000/74168 rows; remaining 64168.
# [hours] Uploaded 11000/74168 rows; remaining 63168.
# [hours] Uploaded 12000/74168 rows; remaining 62168.
# [hours] Uploaded 13000/74168 rows; remaining 61168.
# [hours] Uploaded 14000/74168 rows; remaining 60168.
# [hours] Uploaded 15000/74168 rows; remaining 59168.
# [hours] Uploaded 16000/74168 rows; remaining 58168.
# [hours] Uploaded 17000/74168 rows; remaining 57168.
# [hours] Uploaded 18000/74168 rows; remaining 56168.
# [hours] Uploaded 19000/74168 rows; remaining 55168.
# [hours] Uploaded 20000/74168 rows; remaining 54168.
# [hours] Uploaded 21000/74168 rows; remaining 53168.
# [hours] Uploaded 22000/74168 rows; remaining 52168.
# [hours] Uploaded 23000/74168 rows; remaining 51168.
# [hours] Uploaded 24000/74168 rows; remaining 50168.
# [hours] Uploaded 25000/74168 rows; remaining 49168.
# [hours] Uploaded 26000/74168 rows; remaining 48168.
# [hours] Uploaded 27000/74168 rows; remaining 47168.
# [hours] Uploaded 28000/74168 rows; remaining 46168.
# [hours] Uploaded 29000/74168 rows; remaining 45168.
# [hours] Uploaded 30000/74168 rows; remaining 44168.
# [hours] Uploaded 31000/74168 rows; remaining 43168.
# [hours] Uploaded 32000/74168 rows; remaining 42168.
# [hours] Uploaded 33000/74168 rows; remaining 41168.
# [hours] Uploaded 34000/74168 rows; remaining 40168.
# [hours] Uploaded 35000/74168 rows; remaining 39168.
# [hours] Uploaded 36000/74168 rows; remaining 38168.
# [hours] Uploaded 37000/74168 rows; remaining 37168.
# [hours] Uploaded 38000/74168 rows; remaining 36168.
# [hours] Uploaded 39000/74168 rows; remaining 35168.
# [hours] Uploaded 40000/74168 rows; remaining 34168.
# [hours] Uploaded 41000/74168 rows; remaining 33168.
# [hours] Uploaded 42000/74168 rows; remaining 32168.
# [hours] Uploaded 43000/74168 rows; remaining 31168.
# [hours] Uploaded 44000/74168 rows; remaining 30168.
# [hours] Uploaded 45000/74168 rows; remaining 29168.
# [hours] Uploaded 46000/74168 rows; remaining 28168.
# [hours] Uploaded 47000/74168 rows; remaining 27168.
# [hours] Uploaded 48000/74168 rows; remaining 26168.
# [hours] Uploaded 49000/74168 rows; remaining 25168.
# [hours] Uploaded 50000/74168 rows; remaining 24168.
# [hours] Uploaded 51000/74168 rows; remaining 23168.
# [hours] Uploaded 52000/74168 rows; remaining 22168.
# [hours] Uploaded 53000/74168 rows; remaining 21168.
# [hours] Uploaded 54000/74168 rows; remaining 20168.
# [hours] Uploaded 55000/74168 rows; remaining 19168.
# [hours] Uploaded 56000/74168 rows; remaining 18168.
# [hours] Uploaded 57000/74168 rows; remaining 17168.
# [hours] Uploaded 58000/74168 rows; remaining 16168.
# [hours] Uploaded 59000/74168 rows; remaining 15168.
# [hours] Uploaded 60000/74168 rows; remaining 14168.
# [hours] Uploaded 61000/74168 rows; remaining 13168.
# [hours] Uploaded 62000/74168 rows; remaining 12168.
# [hours] Uploaded 63000/74168 rows; remaining 11168.
# [hours] Uploaded 64000/74168 rows; remaining 10168.
# [hours] Uploaded 65000/74168 rows; remaining 9168.
# [hours] Uploaded 66000/74168 rows; remaining 8168.
# [hours] Uploaded 67000/74168 rows; remaining 7168.
# [hours] Uploaded 68000/74168 rows; remaining 6168.
# [hours] Uploaded 69000/74168 rows; remaining 5168.
# [hours] Uploaded 70000/74168 rows; remaining 4168.
# [hours] Uploaded 71000/74168 rows; remaining 3168.
# [hours] Uploaded 72000/74168 rows; remaining 2168.
# [hours] Uploaded 73000/74168 rows; remaining 1168.
# [hours] Uploaded 74000/74168 rows; remaining 168.
# [hours] Uploaded 74168/74168 rows; remaining 0.
# [review] Upserted 1000/967871 rows; remaining 966871.
# [review] Upserted 2000/967871 rows; remaining 965871.
# [review] Upserted 3000/967871 rows; remaining 964871.
# [review] Upserted 4000/967871 rows; remaining 963871.
# [review] Upserted 5000/967871 rows; remaining 962871.
# [review] Upserted 6000/967871 rows; remaining 961871.
# [review] Upserted 7000/967871 rows; remaining 960871.
# [review] Upserted 8000/967871 rows; remaining 959871.
# [review] Upserted 9000/967871 rows; remaining 958871.
# [review] Upserted 10000/967871 rows; remaining 957871.
# [review] Upserted 11000/967871 rows; remaining 956871.
# [review] Upserted 12000/967871 rows; remaining 955871.
# [review] Upserted 13000/967871 rows; remaining 954871.
# [review] Upserted 14000/967871 rows; remaining 953871.
# [review] Upserted 15000/967871 rows; remaining 952871.
# [review] Upserted 16000/967871 rows; remaining 951871.
# [review] Upserted 17000/967871 rows; remaining 950871.
# [review] Upserted 18000/967871 rows; remaining 949871.
# [review] Upserted 19000/967871 rows; remaining 948871.
# [review] Upserted 20000/967871 rows; remaining 947871.
# [review] Upserted 21000/967871 rows; remaining 946871.
# [review] Upserted 22000/967871 rows; remaining 945871.
# [review] Upserted 23000/967871 rows; remaining 944871.
# [review] Upserted 24000/967871 rows; remaining 943871.
# [review] Upserted 25000/967871 rows; remaining 942871.
# [review] Upserted 26000/967871 rows; remaining 941871.
# [review] Upserted 27000/967871 rows; remaining 940871.
# [review] Upserted 28000/967871 rows; remaining 939871.
# [review] Upserted 29000/967871 rows; remaining 938871.
# [review] Upserted 30000/967871 rows; remaining 937871.
# [review] Upserted 31000/967871 rows; remaining 936871.
# [review] Upserted 32000/967871 rows; remaining 935871.
# [review] Upserted 33000/967871 rows; remaining 934871.
# [review] Upserted 34000/967871 rows; remaining 933871.
# [review] Upserted 35000/967871 rows; remaining 932871.
# [review] Upserted 36000/967871 rows; remaining 931871.
# [review] Upserted 37000/967871 rows; remaining 930871.
# [review] Upserted 38000/967871 rows; remaining 929871.
# [review] Upserted 39000/967871 rows; remaining 928871.
# [review] Upserted 40000/967871 rows; remaining 927871.
# [review] Upserted 41000/967871 rows; remaining 926871.
# [review] Upserted 42000/967871 rows; remaining 925871.
# [review] Upserted 43000/967871 rows; remaining 924871.
# [review] Upserted 44000/967871 rows; remaining 923871.
# [review] Upserted 45000/967871 rows; remaining 922871.
# [review] Upserted 46000/967871 rows; remaining 921871.
# [review] Upserted 47000/967871 rows; remaining 920871.
# [review] Upserted 48000/967871 rows; remaining 919871.
# [review] Upserted 49000/967871 rows; remaining 918871.
# [review] Upserted 50000/967871 rows; remaining 917871.
# [review] Upserted 51000/967871 rows; remaining 916871.
# [review] Upserted 52000/967871 rows; remaining 915871.
# [review] Upserted 53000/967871 rows; remaining 914871.
# [review] Upserted 54000/967871 rows; remaining 913871.
# [review] Upserted 55000/967871 rows; remaining 912871.
# [review] Upserted 56000/967871 rows; remaining 911871.
# [review] Upserted 57000/967871 rows; remaining 910871.
# [review] Upserted 58000/967871 rows; remaining 909871.
# [review] Upserted 59000/967871 rows; remaining 908871.
# [review] Upserted 60000/967871 rows; remaining 907871.
# [review] Upserted 61000/967871 rows; remaining 906871.
# [review] Upserted 62000/967871 rows; remaining 905871.
# [review] Upserted 63000/967871 rows; remaining 904871.
# [review] Upserted 64000/967871 rows; remaining 903871.
# [review] Upserted 65000/967871 rows; remaining 902871.
# [review] Upserted 66000/967871 rows; remaining 901871.
# [review] Upserted 67000/967871 rows; remaining 900871.
# [review] Upserted 68000/967871 rows; remaining 899871.
# [review] Upserted 69000/967871 rows; remaining 898871.
# [review] Upserted 70000/967871 rows; remaining 897871.
# [review] Upserted 71000/967871 rows; remaining 896871.
# [review] Upserted 72000/967871 rows; remaining 895871.
# [review] Upserted 73000/967871 rows; remaining 894871.
# [review] Upserted 74000/967871 rows; remaining 893871.
# [review] Upserted 75000/967871 rows; remaining 892871.
# [review] Upserted 76000/967871 rows; remaining 891871.
# [review] Upserted 77000/967871 rows; remaining 890871.
# [review] Upserted 78000/967871 rows; remaining 889871.
# [review] Upserted 79000/967871 rows; remaining 888871.
# [review] Upserted 80000/967871 rows; remaining 887871.
# [review] Upserted 81000/967871 rows; remaining 886871.
# [review] Upserted 82000/967871 rows; remaining 885871.
# [review] Upserted 83000/967871 rows; remaining 884871.
# [review] Upserted 84000/967871 rows; remaining 883871.
# [review] Upserted 85000/967871 rows; remaining 882871.
# [review] Upserted 86000/967871 rows; remaining 881871.
# [review] Upserted 87000/967871 rows; remaining 880871.
# [review] Upserted 88000/967871 rows; remaining 879871.
# [review] Upserted 89000/967871 rows; remaining 878871.
# [review] Upserted 90000/967871 rows; remaining 877871.
# [review] Upserted 91000/967871 rows; remaining 876871.
# [review] Upserted 92000/967871 rows; remaining 875871.
# [review] Upserted 93000/967871 rows; remaining 874871.
# [review] Upserted 94000/967871 rows; remaining 873871.
# [review] Upserted 95000/967871 rows; remaining 872871.
# [review] Upserted 96000/967871 rows; remaining 871871.
# [review] Upserted 97000/967871 rows; remaining 870871.
# [review] Upserted 98000/967871 rows; remaining 869871.
# [review] Upserted 99000/967871 rows; remaining 868871.
# [review] Upserted 100000/967871 rows; remaining 867871.
# [review] Upserted 101000/967871 rows; remaining 866871.
# [review] Upserted 102000/967871 rows; remaining 865871.
# [review] Upserted 103000/967871 rows; remaining 864871.
# [review] Upserted 104000/967871 rows; remaining 863871.
# [review] Upserted 105000/967871 rows; remaining 862871.
# [review] Upserted 106000/967871 rows; remaining 861871.
# [review] Upserted 107000/967871 rows; remaining 860871.
# [review] Upserted 108000/967871 rows; remaining 859871.
# [review] Upserted 109000/967871 rows; remaining 858871.
# [review] Upserted 110000/967871 rows; remaining 857871.
# [review] Upserted 111000/967871 rows; remaining 856871.
# [review] Upserted 112000/967871 rows; remaining 855871.
# [review] Upserted 113000/967871 rows; remaining 854871.
# [review] Upserted 114000/967871 rows; remaining 853871.
# [review] Upserted 115000/967871 rows; remaining 852871.
# [review] Upserted 116000/967871 rows; remaining 851871.
# [review] Upserted 117000/967871 rows; remaining 850871.
# [review] Upserted 118000/967871 rows; remaining 849871.
# [review] Upserted 119000/967871 rows; remaining 848871.
# [review] Upserted 120000/967871 rows; remaining 847871.
# [review] Upserted 121000/967871 rows; remaining 846871.
# [review] Upserted 122000/967871 rows; remaining 845871.
# [review] Upserted 123000/967871 rows; remaining 844871.
# [review] Upserted 124000/967871 rows; remaining 843871.
# [review] Upserted 125000/967871 rows; remaining 842871.
# [review] Upserted 126000/967871 rows; remaining 841871.
# [review] Upserted 127000/967871 rows; remaining 840871.
# [review] Upserted 128000/967871 rows; remaining 839871.
# [review] Upserted 129000/967871 rows; remaining 838871.
# [review] Upserted 130000/967871 rows; remaining 837871.
# [review] Upserted 131000/967871 rows; remaining 836871.
# [review] Upserted 132000/967871 rows; remaining 835871.
# [review] Upserted 133000/967871 rows; remaining 834871.
# [review] Upserted 134000/967871 rows; remaining 833871.
# [review] Upserted 135000/967871 rows; remaining 832871.
# [review] Upserted 136000/967871 rows; remaining 831871.
# [review] Upserted 137000/967871 rows; remaining 830871.
# [review] Upserted 138000/967871 rows; remaining 829871.
# [review] Upserted 139000/967871 rows; remaining 828871.
# [review] Upserted 140000/967871 rows; remaining 827871.
# [review] Upserted 141000/967871 rows; remaining 826871.
# [review] Upserted 142000/967871 rows; remaining 825871.
# [review] Upserted 143000/967871 rows; remaining 824871.
# [review] Upserted 144000/967871 rows; remaining 823871.
# [review] Upserted 145000/967871 rows; remaining 822871.
# [review] Upserted 146000/967871 rows; remaining 821871.
# [review] Upserted 147000/967871 rows; remaining 820871.
# [review] Upserted 148000/967871 rows; remaining 819871.
# [review] Upserted 149000/967871 rows; remaining 818871.
# [review] Upserted 150000/967871 rows; remaining 817871.
# [review] Upserted 151000/967871 rows; remaining 816871.
# [review] Upserted 152000/967871 rows; remaining 815871.
# [review] Upserted 153000/967871 rows; remaining 814871.
# [review] Upserted 154000/967871 rows; remaining 813871.
# [review] Upserted 155000/967871 rows; remaining 812871.
# [review] Upserted 156000/967871 rows; remaining 811871.
# [review] Upserted 157000/967871 rows; remaining 810871.
# [review] Upserted 158000/967871 rows; remaining 809871.
# [review] Upserted 159000/967871 rows; remaining 808871.
# [review] Upserted 160000/967871 rows; remaining 807871.
# [review] Upserted 161000/967871 rows; remaining 806871.
# [review] Upserted 162000/967871 rows; remaining 805871.
# [review] Upserted 163000/967871 rows; remaining 804871.
# [review] Upserted 164000/967871 rows; remaining 803871.
# [review] Upserted 165000/967871 rows; remaining 802871.
# [review] Upserted 166000/967871 rows; remaining 801871.
# [review] Upserted 167000/967871 rows; remaining 800871.
# [review] Upserted 168000/967871 rows; remaining 799871.
# [review] Upserted 169000/967871 rows; remaining 798871.
# [review] Upserted 170000/967871 rows; remaining 797871.
# [review] Upserted 171000/967871 rows; remaining 796871.
# [review] Upserted 172000/967871 rows; remaining 795871.
# [review] Upserted 173000/967871 rows; remaining 794871.
# [review] Upserted 174000/967871 rows; remaining 793871.
# [review] Upserted 175000/967871 rows; remaining 792871.
# [review] Upserted 176000/967871 rows; remaining 791871.
# [review] Upserted 177000/967871 rows; remaining 790871.
# [review] Upserted 178000/967871 rows; remaining 789871.
# [review] Upserted 179000/967871 rows; remaining 788871.
# [review] Upserted 180000/967871 rows; remaining 787871.
# [review] Upserted 181000/967871 rows; remaining 786871.
# [review] Upserted 182000/967871 rows; remaining 785871.
# [review] Upserted 183000/967871 rows; remaining 784871.
# [review] Upserted 184000/967871 rows; remaining 783871.
# [review] Upserted 185000/967871 rows; remaining 782871.
# [review] Upserted 186000/967871 rows; remaining 781871.
# [review] Upserted 187000/967871 rows; remaining 780871.
# [review] Upserted 188000/967871 rows; remaining 779871.
# [review] Upserted 189000/967871 rows; remaining 778871.
# [review] Upserted 190000/967871 rows; remaining 777871.
# [review] Upserted 191000/967871 rows; remaining 776871.
# [review] Upserted 192000/967871 rows; remaining 775871.
# [review] Upserted 193000/967871 rows; remaining 774871.
# [review] Upserted 194000/967871 rows; remaining 773871.
# [review] Upserted 195000/967871 rows; remaining 772871.
# [review] Upserted 196000/967871 rows; remaining 771871.
# [review] Upserted 197000/967871 rows; remaining 770871.
# [review] Upserted 198000/967871 rows; remaining 769871.
# [review] Upserted 199000/967871 rows; remaining 768871.
# [review] Upserted 200000/967871 rows; remaining 767871.
# [review] Upserted 201000/967871 rows; remaining 766871.
# [review] Upserted 202000/967871 rows; remaining 765871.
# [review] Upserted 203000/967871 rows; remaining 764871.
# [review] Upserted 204000/967871 rows; remaining 763871.
# [review] Upserted 205000/967871 rows; remaining 762871.
# [review] Upserted 206000/967871 rows; remaining 761871.
# [review] Upserted 207000/967871 rows; remaining 760871.
# [review] Upserted 208000/967871 rows; remaining 759871.
# [review] Upserted 209000/967871 rows; remaining 758871.
# [review] Upserted 210000/967871 rows; remaining 757871.
# [review] Upserted 211000/967871 rows; remaining 756871.
# [review] Upserted 212000/967871 rows; remaining 755871.
# [review] Upserted 213000/967871 rows; remaining 754871.
# [review] Upserted 214000/967871 rows; remaining 753871.
# [review] Upserted 215000/967871 rows; remaining 752871.
# [review] Upserted 216000/967871 rows; remaining 751871.
# [review] Upserted 217000/967871 rows; remaining 750871.
# [review] Upserted 218000/967871 rows; remaining 749871.
# [review] Upserted 219000/967871 rows; remaining 748871.
# [review] Upserted 220000/967871 rows; remaining 747871.
# [review] Upserted 221000/967871 rows; remaining 746871.
# [review] Upserted 222000/967871 rows; remaining 745871.
# [review] Upserted 223000/967871 rows; remaining 744871.
# [review] Upserted 224000/967871 rows; remaining 743871.
# [review] Upserted 225000/967871 rows; remaining 742871.
# [review] Upserted 226000/967871 rows; remaining 741871.
# [review] Upserted 227000/967871 rows; remaining 740871.
# [review] Upserted 228000/967871 rows; remaining 739871.
# [review] Upserted 229000/967871 rows; remaining 738871.
# [review] Upserted 230000/967871 rows; remaining 737871.
# [review] Upserted 231000/967871 rows; remaining 736871.
# [review] Upserted 232000/967871 rows; remaining 735871.
# [review] Upserted 233000/967871 rows; remaining 734871.
# [review] Upserted 234000/967871 rows; remaining 733871.
# [review] Upserted 235000/967871 rows; remaining 732871.
# [review] Upserted 236000/967871 rows; remaining 731871.
# [review] Upserted 237000/967871 rows; remaining 730871.
# [review] Upserted 238000/967871 rows; remaining 729871.
# [review] Upserted 239000/967871 rows; remaining 728871.
# [review] Upserted 240000/967871 rows; remaining 727871.
# [review] Upserted 241000/967871 rows; remaining 726871.
# [review] Upserted 242000/967871 rows; remaining 725871.
# [review] Upserted 243000/967871 rows; remaining 724871.
# [review] Upserted 244000/967871 rows; remaining 723871.
# [review] Upserted 245000/967871 rows; remaining 722871.
# [review] Upserted 246000/967871 rows; remaining 721871.
# [review] Upserted 247000/967871 rows; remaining 720871.
# [review] Upserted 248000/967871 rows; remaining 719871.
# [review] Upserted 249000/967871 rows; remaining 718871.
# [review] Upserted 250000/967871 rows; remaining 717871.
# [review] Upserted 251000/967871 rows; remaining 716871.
# [review] Upserted 252000/967871 rows; remaining 715871.
# [review] Upserted 253000/967871 rows; remaining 714871.
# [review] Upserted 254000/967871 rows; remaining 713871.
# [review] Upserted 255000/967871 rows; remaining 712871.
# [review] Upserted 256000/967871 rows; remaining 711871.
# [review] Upserted 257000/967871 rows; remaining 710871.
# [review] Upserted 258000/967871 rows; remaining 709871.
# [review] Upserted 259000/967871 rows; remaining 708871.
# [review] Upserted 260000/967871 rows; remaining 707871.
# [review] Upserted 261000/967871 rows; remaining 706871.
# [review] Upserted 262000/967871 rows; remaining 705871.
# [review] Upserted 263000/967871 rows; remaining 704871.
# [review] Upserted 264000/967871 rows; remaining 703871.
# [review] Upserted 265000/967871 rows; remaining 702871.
# [review] Upserted 266000/967871 rows; remaining 701871.
# [review] Upserted 267000/967871 rows; remaining 700871.
# [review] Upserted 268000/967871 rows; remaining 699871.
# [review] Upserted 269000/967871 rows; remaining 698871.
# [review] Upserted 270000/967871 rows; remaining 697871.
# [review] Upserted 271000/967871 rows; remaining 696871.
# [review] Upserted 272000/967871 rows; remaining 695871.
# [review] Upserted 273000/967871 rows; remaining 694871.
# [review] Upserted 274000/967871 rows; remaining 693871.
# [review] Upserted 275000/967871 rows; remaining 692871.
# [review] Upserted 276000/967871 rows; remaining 691871.
# [review] Upserted 277000/967871 rows; remaining 690871.
# [review] Upserted 278000/967871 rows; remaining 689871.
# [review] Upserted 279000/967871 rows; remaining 688871.
# [review] Upserted 280000/967871 rows; remaining 687871.
# [review] Upserted 281000/967871 rows; remaining 686871.
# [review] Upserted 282000/967871 rows; remaining 685871.
# [review] Upserted 283000/967871 rows; remaining 684871.
# [review] Upserted 284000/967871 rows; remaining 683871.
# [review] Upserted 285000/967871 rows; remaining 682871.
# [review] Upserted 286000/967871 rows; remaining 681871.
# [review] Upserted 287000/967871 rows; remaining 680871.
# [review] Upserted 288000/967871 rows; remaining 679871.
# [review] Upserted 289000/967871 rows; remaining 678871.
# [review] Upserted 290000/967871 rows; remaining 677871.
# [review] Upserted 291000/967871 rows; remaining 676871.
# [review] Upserted 292000/967871 rows; remaining 675871.
# [review] Upserted 293000/967871 rows; remaining 674871.
# [review] Upserted 294000/967871 rows; remaining 673871.
# [review] Upserted 295000/967871 rows; remaining 672871.
# [review] Upserted 296000/967871 rows; remaining 671871.
# [review] Upserted 297000/967871 rows; remaining 670871.
# [review] Upserted 298000/967871 rows; remaining 669871.
# [review] Upserted 299000/967871 rows; remaining 668871.
# [review] Upserted 300000/967871 rows; remaining 667871.
# [review] Upserted 301000/967871 rows; remaining 666871.
# [review] Upserted 302000/967871 rows; remaining 665871.
# [review] Upserted 303000/967871 rows; remaining 664871.
# [review] Upserted 304000/967871 rows; remaining 663871.
# [review] Upserted 305000/967871 rows; remaining 662871.
# [review] Upserted 306000/967871 rows; remaining 661871.
# [review] Upserted 307000/967871 rows; remaining 660871.
# [review] Upserted 308000/967871 rows; remaining 659871.
# [review] Upserted 309000/967871 rows; remaining 658871.
# [review] Upserted 310000/967871 rows; remaining 657871.
# [review] Upserted 311000/967871 rows; remaining 656871.
# [review] Upserted 312000/967871 rows; remaining 655871.
# [review] Upserted 313000/967871 rows; remaining 654871.
# [review] Upserted 314000/967871 rows; remaining 653871.
# [review] Upserted 315000/967871 rows; remaining 652871.
# [review] Upserted 316000/967871 rows; remaining 651871.
# [review] Upserted 317000/967871 rows; remaining 650871.
# [review] Upserted 318000/967871 rows; remaining 649871.
# [review] Upserted 319000/967871 rows; remaining 648871.
# [review] Upserted 320000/967871 rows; remaining 647871.
# [review] Upserted 321000/967871 rows; remaining 646871.
# [review] Upserted 322000/967871 rows; remaining 645871.
# [review] Upserted 323000/967871 rows; remaining 644871.
# [review] Upserted 324000/967871 rows; remaining 643871.
# [review] Upserted 325000/967871 rows; remaining 642871.
# [review] Upserted 326000/967871 rows; remaining 641871.
# [review] Upserted 327000/967871 rows; remaining 640871.
# [review] Upserted 328000/967871 rows; remaining 639871.
# [review] Upserted 329000/967871 rows; remaining 638871.
# [review] Upserted 330000/967871 rows; remaining 637871.
# [review] Upserted 331000/967871 rows; remaining 636871.
# [review] Upserted 332000/967871 rows; remaining 635871.
# [review] Upserted 333000/967871 rows; remaining 634871.
# [review] Upserted 334000/967871 rows; remaining 633871.
# [review] Upserted 335000/967871 rows; remaining 632871.
# [review] Upserted 336000/967871 rows; remaining 631871.
# [review] Upserted 337000/967871 rows; remaining 630871.
# [review] Upserted 338000/967871 rows; remaining 629871.
# [review] Upserted 339000/967871 rows; remaining 628871.
# [review] Upserted 340000/967871 rows; remaining 627871.
# [review] Upserted 341000/967871 rows; remaining 626871.
# [review] Upserted 342000/967871 rows; remaining 625871.
# [review] Upserted 343000/967871 rows; remaining 624871.
# [review] Upserted 344000/967871 rows; remaining 623871.
# [review] Upserted 345000/967871 rows; remaining 622871.
# [review] Upserted 346000/967871 rows; remaining 621871.
# [review] Upserted 347000/967871 rows; remaining 620871.
# [review] Upserted 348000/967871 rows; remaining 619871.
# [review] Upserted 349000/967871 rows; remaining 618871.
# [review] Upserted 350000/967871 rows; remaining 617871.
# [review] Upserted 351000/967871 rows; remaining 616871.
# [review] Upserted 352000/967871 rows; remaining 615871.
# [review] Upserted 353000/967871 rows; remaining 614871.
# [review] Upserted 354000/967871 rows; remaining 613871.
# [review] Upserted 355000/967871 rows; remaining 612871.
# [review] Upserted 356000/967871 rows; remaining 611871.
# [review] Upserted 357000/967871 rows; remaining 610871.
# [review] Upserted 358000/967871 rows; remaining 609871.
# [review] Upserted 359000/967871 rows; remaining 608871.
# [review] Upserted 360000/967871 rows; remaining 607871.
# [review] Upserted 361000/967871 rows; remaining 606871.
# [review] Upserted 362000/967871 rows; remaining 605871.
# [review] Upserted 363000/967871 rows; remaining 604871.
# [review] Upserted 364000/967871 rows; remaining 603871.
# [review] Upserted 365000/967871 rows; remaining 602871.
# [review] Upserted 366000/967871 rows; remaining 601871.
# [review] Upserted 367000/967871 rows; remaining 600871.
# [review] Upserted 368000/967871 rows; remaining 599871.
# [review] Upserted 369000/967871 rows; remaining 598871.
# [review] Upserted 370000/967871 rows; remaining 597871.
# [review] Upserted 371000/967871 rows; remaining 596871.
# [review] Upserted 372000/967871 rows; remaining 595871.
# [review] Upserted 373000/967871 rows; remaining 594871.
# [review] Upserted 374000/967871 rows; remaining 593871.
# [review] Upserted 375000/967871 rows; remaining 592871.
# [review] Upserted 376000/967871 rows; remaining 591871.
# [review] Upserted 377000/967871 rows; remaining 590871.
# [review] Upserted 378000/967871 rows; remaining 589871.
# [review] Upserted 379000/967871 rows; remaining 588871.
# [review] Upserted 380000/967871 rows; remaining 587871.
# [review] Upserted 381000/967871 rows; remaining 586871.
# [review] Upserted 382000/967871 rows; remaining 585871.
# [review] Upserted 383000/967871 rows; remaining 584871.
# [review] Upserted 384000/967871 rows; remaining 583871.
# [review] Upserted 385000/967871 rows; remaining 582871.
# [review] Upserted 386000/967871 rows; remaining 581871.
# [review] Upserted 387000/967871 rows; remaining 580871.
# [review] Upserted 388000/967871 rows; remaining 579871.
# [review] Upserted 389000/967871 rows; remaining 578871.
# [review] Upserted 390000/967871 rows; remaining 577871.
# [review] Upserted 391000/967871 rows; remaining 576871.
# [review] Upserted 392000/967871 rows; remaining 575871.
# [review] Upserted 393000/967871 rows; remaining 574871.
# [review] Upserted 394000/967871 rows; remaining 573871.
# [review] Upserted 395000/967871 rows; remaining 572871.
# [review] Upserted 396000/967871 rows; remaining 571871.
# [review] Upserted 397000/967871 rows; remaining 570871.
# [review] Upserted 398000/967871 rows; remaining 569871.
# [review] Upserted 399000/967871 rows; remaining 568871.
# [review] Upserted 400000/967871 rows; remaining 567871.
# [review] Upserted 401000/967871 rows; remaining 566871.
# [review] Upserted 402000/967871 rows; remaining 565871.
# [review] Upserted 403000/967871 rows; remaining 564871.
# [review] Upserted 404000/967871 rows; remaining 563871.
# [review] Upserted 405000/967871 rows; remaining 562871.
# [review] Upserted 406000/967871 rows; remaining 561871.
# [review] Upserted 407000/967871 rows; remaining 560871.
# [review] Upserted 408000/967871 rows; remaining 559871.
# [review] Upserted 409000/967871 rows; remaining 558871.
# [review] Upserted 410000/967871 rows; remaining 557871.
# [review] Upserted 411000/967871 rows; remaining 556871.
# [review] Upserted 412000/967871 rows; remaining 555871.
# [review] Upserted 413000/967871 rows; remaining 554871.
# [review] Upserted 414000/967871 rows; remaining 553871.
# [review] Upserted 415000/967871 rows; remaining 552871.
# [review] Upserted 416000/967871 rows; remaining 551871.
# [review] Upserted 417000/967871 rows; remaining 550871.
# [review] Upserted 418000/967871 rows; remaining 549871.
# [review] Upserted 419000/967871 rows; remaining 548871.
# [review] Upserted 420000/967871 rows; remaining 547871.
# [review] Upserted 421000/967871 rows; remaining 546871.
# [review] Upserted 422000/967871 rows; remaining 545871.
# [review] Upserted 423000/967871 rows; remaining 544871.
# [review] Upserted 424000/967871 rows; remaining 543871.
# [review] Upserted 425000/967871 rows; remaining 542871.
# [review] Upserted 426000/967871 rows; remaining 541871.
# [review] Upserted 427000/967871 rows; remaining 540871.
# [review] Upserted 428000/967871 rows; remaining 539871.
# [review] Upserted 429000/967871 rows; remaining 538871.
# [review] Upserted 430000/967871 rows; remaining 537871.
# [review] Upserted 431000/967871 rows; remaining 536871.
# [review] Upserted 432000/967871 rows; remaining 535871.
# [review] Upserted 433000/967871 rows; remaining 534871.
# [review] Upserted 434000/967871 rows; remaining 533871.
# [review] Upserted 435000/967871 rows; remaining 532871.
# [review] Upserted 436000/967871 rows; remaining 531871.
# [review] Upserted 437000/967871 rows; remaining 530871.
# [review] Upserted 438000/967871 rows; remaining 529871.
# [review] Upserted 439000/967871 rows; remaining 528871.
# [review] Upserted 440000/967871 rows; remaining 527871.
# [review] Upserted 441000/967871 rows; remaining 526871.
# [review] Upserted 442000/967871 rows; remaining 525871.
# [review] Upserted 443000/967871 rows; remaining 524871.
# [review] Upserted 444000/967871 rows; remaining 523871.
# [review] Upserted 445000/967871 rows; remaining 522871.
# [review] Upserted 446000/967871 rows; remaining 521871.
# [review] Upserted 447000/967871 rows; remaining 520871.
# [review] Upserted 448000/967871 rows; remaining 519871.
# [review] Upserted 449000/967871 rows; remaining 518871.
# [review] Upserted 450000/967871 rows; remaining 517871.
# [review] Upserted 451000/967871 rows; remaining 516871.
# [review] Upserted 452000/967871 rows; remaining 515871.
# [review] Upserted 453000/967871 rows; remaining 514871.
# [review] Upserted 454000/967871 rows; remaining 513871.
# [review] Upserted 455000/967871 rows; remaining 512871.
# [review] Upserted 456000/967871 rows; remaining 511871.
# [review] Upserted 457000/967871 rows; remaining 510871.
# [review] Upserted 458000/967871 rows; remaining 509871.
# [review] Upserted 459000/967871 rows; remaining 508871.
# [review] Upserted 460000/967871 rows; remaining 507871.
# [review] Upserted 461000/967871 rows; remaining 506871.
# [review] Upserted 462000/967871 rows; remaining 505871.
# [review] Upserted 463000/967871 rows; remaining 504871.
# [review] Upserted 464000/967871 rows; remaining 503871.
# [review] Upserted 465000/967871 rows; remaining 502871.
# [review] Upserted 466000/967871 rows; remaining 501871.
# [review] Upserted 467000/967871 rows; remaining 500871.
# [review] Upserted 468000/967871 rows; remaining 499871.
# [review] Upserted 469000/967871 rows; remaining 498871.
# [review] Upserted 470000/967871 rows; remaining 497871.
# [review] Upserted 471000/967871 rows; remaining 496871.
# [review] Upserted 472000/967871 rows; remaining 495871.
# [review] Upserted 473000/967871 rows; remaining 494871.
# [review] Upserted 474000/967871 rows; remaining 493871.
# [review] Upserted 475000/967871 rows; remaining 492871.
# [review] Upserted 476000/967871 rows; remaining 491871.
# [review] Upserted 477000/967871 rows; remaining 490871.
# [review] Upserted 478000/967871 rows; remaining 489871.
# [review] Upserted 479000/967871 rows; remaining 488871.
# [review] Upserted 480000/967871 rows; remaining 487871.
# [review] Upserted 481000/967871 rows; remaining 486871.
# [review] Upserted 482000/967871 rows; remaining 485871.
# [review] Upserted 483000/967871 rows; remaining 484871.
# [review] Upserted 484000/967871 rows; remaining 483871.
# [review] Upserted 485000/967871 rows; remaining 482871.
# [review] Upserted 486000/967871 rows; remaining 481871.
# [review] Upserted 487000/967871 rows; remaining 480871.
# [review] Upserted 488000/967871 rows; remaining 479871.
# [review] Upserted 489000/967871 rows; remaining 478871.
# [review] Upserted 490000/967871 rows; remaining 477871.
# [review] Upserted 491000/967871 rows; remaining 476871.
# [review] Upserted 492000/967871 rows; remaining 475871.
# [review] Upserted 493000/967871 rows; remaining 474871.
# [review] Upserted 494000/967871 rows; remaining 473871.
# [review] Upserted 495000/967871 rows; remaining 472871.
# [review] Upserted 496000/967871 rows; remaining 471871.
# [review] Upserted 497000/967871 rows; remaining 470871.
# [review] Upserted 498000/967871 rows; remaining 469871.
# [review] Upserted 499000/967871 rows; remaining 468871.
# [review] Upserted 500000/967871 rows; remaining 467871.
# [review] Upserted 501000/967871 rows; remaining 466871.
# [review] Upserted 502000/967871 rows; remaining 465871.
# [review] Upserted 503000/967871 rows; remaining 464871.
# [review] Upserted 504000/967871 rows; remaining 463871.
# [review] Upserted 505000/967871 rows; remaining 462871.
# [review] Upserted 506000/967871 rows; remaining 461871.
# [review] Upserted 507000/967871 rows; remaining 460871.
# [review] Upserted 508000/967871 rows; remaining 459871.
# [review] Upserted 509000/967871 rows; remaining 458871.
# [review] Upserted 510000/967871 rows; remaining 457871.
# [review] Upserted 511000/967871 rows; remaining 456871.
# [review] Upserted 512000/967871 rows; remaining 455871.
# [review] Upserted 513000/967871 rows; remaining 454871.
# [review] Upserted 514000/967871 rows; remaining 453871.
# [review] Upserted 515000/967871 rows; remaining 452871.
# [review] Upserted 516000/967871 rows; remaining 451871.
# [review] Upserted 517000/967871 rows; remaining 450871.
# [review] Upserted 518000/967871 rows; remaining 449871.
# [review] Upserted 519000/967871 rows; remaining 448871.
# [review] Upserted 520000/967871 rows; remaining 447871.
# [review] Upserted 521000/967871 rows; remaining 446871.
# [review] Upserted 522000/967871 rows; remaining 445871.
# [review] Upserted 523000/967871 rows; remaining 444871.
# [review] Upserted 524000/967871 rows; remaining 443871.
# [review] Upserted 525000/967871 rows; remaining 442871.
# [review] Upserted 526000/967871 rows; remaining 441871.
# [review] Upserted 527000/967871 rows; remaining 440871.
# [review] Upserted 528000/967871 rows; remaining 439871.
# [review] Upserted 529000/967871 rows; remaining 438871.
# [review] Upserted 530000/967871 rows; remaining 437871.
# [review] Upserted 531000/967871 rows; remaining 436871.
# [review] Upserted 532000/967871 rows; remaining 435871.
# [review] Upserted 533000/967871 rows; remaining 434871.
# [review] Upserted 534000/967871 rows; remaining 433871.
# [review] Upserted 535000/967871 rows; remaining 432871.
# [review] Upserted 536000/967871 rows; remaining 431871.
# [review] Upserted 537000/967871 rows; remaining 430871.
# [review] Upserted 538000/967871 rows; remaining 429871.
# [review] Upserted 539000/967871 rows; remaining 428871.
# [review] Upserted 540000/967871 rows; remaining 427871.
# [review] Upserted 541000/967871 rows; remaining 426871.
# [review] Upserted 542000/967871 rows; remaining 425871.
# [review] Upserted 543000/967871 rows; remaining 424871.
# [review] Upserted 544000/967871 rows; remaining 423871.
# [review] Upserted 545000/967871 rows; remaining 422871.
# [review] Upserted 546000/967871 rows; remaining 421871.
# [review] Upserted 547000/967871 rows; remaining 420871.
# [review] Upserted 548000/967871 rows; remaining 419871.
# [review] Upserted 549000/967871 rows; remaining 418871.
# [review] Upserted 550000/967871 rows; remaining 417871.
# [review] Upserted 551000/967871 rows; remaining 416871.
# [review] Upserted 552000/967871 rows; remaining 415871.
# [review] Upserted 553000/967871 rows; remaining 414871.
# [review] Upserted 554000/967871 rows; remaining 413871.
# [review] Upserted 555000/967871 rows; remaining 412871.
# [review] Upserted 556000/967871 rows; remaining 411871.
# [review] Upserted 557000/967871 rows; remaining 410871.
# [review] Upserted 558000/967871 rows; remaining 409871.
# [review] Upserted 559000/967871 rows; remaining 408871.
# [review] Upserted 560000/967871 rows; remaining 407871.
# [review] Upserted 561000/967871 rows; remaining 406871.
# [review] Upserted 562000/967871 rows; remaining 405871.
# [review] Upserted 563000/967871 rows; remaining 404871.
# [review] Upserted 564000/967871 rows; remaining 403871.
# [review] Upserted 565000/967871 rows; remaining 402871.
# [review] Upserted 566000/967871 rows; remaining 401871.
# [review] Upserted 567000/967871 rows; remaining 400871.
# [review] Upserted 568000/967871 rows; remaining 399871.
# [review] Upserted 569000/967871 rows; remaining 398871.
# [review] Upserted 570000/967871 rows; remaining 397871.
# [review] Upserted 571000/967871 rows; remaining 396871.
# [review] Upserted 572000/967871 rows; remaining 395871.
# [review] Upserted 573000/967871 rows; remaining 394871.
# [review] Upserted 574000/967871 rows; remaining 393871.
# [review] Upserted 575000/967871 rows; remaining 392871.
# [review] Upserted 576000/967871 rows; remaining 391871.
# [review] Upserted 577000/967871 rows; remaining 390871.
# [review] Upserted 578000/967871 rows; remaining 389871.
# [review] Upserted 579000/967871 rows; remaining 388871.
# [review] Upserted 580000/967871 rows; remaining 387871.
# [review] Upserted 581000/967871 rows; remaining 386871.
# [review] Upserted 582000/967871 rows; remaining 385871.
# [review] Upserted 583000/967871 rows; remaining 384871.
# [review] Upserted 584000/967871 rows; remaining 383871.
# [review] Upserted 585000/967871 rows; remaining 382871.
# [review] Upserted 586000/967871 rows; remaining 381871.
# [review] Upserted 587000/967871 rows; remaining 380871.
# [review] Upserted 588000/967871 rows; remaining 379871.
# [review] Upserted 589000/967871 rows; remaining 378871.
# [review] Upserted 590000/967871 rows; remaining 377871.
# [review] Upserted 591000/967871 rows; remaining 376871.
# [review] Upserted 592000/967871 rows; remaining 375871.
# [review] Upserted 593000/967871 rows; remaining 374871.
# [review] Upserted 594000/967871 rows; remaining 373871.
# [review] Upserted 595000/967871 rows; remaining 372871.
# [review] Upserted 596000/967871 rows; remaining 371871.
# [review] Upserted 597000/967871 rows; remaining 370871.
# [review] Upserted 598000/967871 rows; remaining 369871.
# [review] Upserted 599000/967871 rows; remaining 368871.
# [review] Upserted 600000/967871 rows; remaining 367871.
# [review] Upserted 601000/967871 rows; remaining 366871.
# [review] Upserted 602000/967871 rows; remaining 365871.
# [review] Upserted 603000/967871 rows; remaining 364871.
# [review] Upserted 604000/967871 rows; remaining 363871.
# [review] Upserted 605000/967871 rows; remaining 362871.
# [review] Upserted 606000/967871 rows; remaining 361871.
# [review] Upserted 607000/967871 rows; remaining 360871.
# [review] Upserted 608000/967871 rows; remaining 359871.
# [review] Upserted 609000/967871 rows; remaining 358871.
# [review] Upserted 610000/967871 rows; remaining 357871.
# [review] Upserted 611000/967871 rows; remaining 356871.
# [review] Upserted 612000/967871 rows; remaining 355871.
# [review] Upserted 613000/967871 rows; remaining 354871.
# [review] Upserted 614000/967871 rows; remaining 353871.
# [review] Upserted 615000/967871 rows; remaining 352871.
# [review] Upserted 616000/967871 rows; remaining 351871.
# [review] Upserted 617000/967871 rows; remaining 350871.
# [review] Upserted 618000/967871 rows; remaining 349871.
# [review] Upserted 619000/967871 rows; remaining 348871.
# [review] Upserted 620000/967871 rows; remaining 347871.
# [review] Upserted 621000/967871 rows; remaining 346871.
# [review] Upserted 622000/967871 rows; remaining 345871.
# [review] Upserted 623000/967871 rows; remaining 344871.
# [review] Upserted 624000/967871 rows; remaining 343871.
# [review] Upserted 625000/967871 rows; remaining 342871.
# [review] Upserted 626000/967871 rows; remaining 341871.
# [review] Upserted 627000/967871 rows; remaining 340871.
# [review] Upserted 628000/967871 rows; remaining 339871.
# [review] Upserted 629000/967871 rows; remaining 338871.
# [review] Upserted 630000/967871 rows; remaining 337871.
# [review] Upserted 631000/967871 rows; remaining 336871.
# [review] Upserted 632000/967871 rows; remaining 335871.
# ...
# [review] Upserted 685000/967871 rows; remaining 282871.
# [review] Upserted 686000/967871 rows; remaining 281871.
# [review] Upserted 687000/967871 rows; remaining 280871.
# [review] Upserted 688000/967871 rows; remaining 279871.
# [review] Upserted 689000/967871 rows; remaining 278871.
# [review] Upserted 690000/967871 rows; remaining 277871.
# [review] Upserted 691000/967871 rows; remaining 276871.
# [review] Upserted 692000/967871 rows; remaining 275871.
# [review] Upserted 693000/967871 rows; remaining 274871.
# [review] Upserted 694000/967871 rows; remaining 273871.
# [review] Upserted 695000/967871 rows; remaining 272871.
# [review] Upserted 696000/967871 rows; remaining 271871.
# [review] Upserted 697000/967871 rows; remaining 270871.
# [review] Upserted 698000/967871 rows; remaining 269871.
# [review] Upserted 699000/967871 rows; remaining 268871.
# [review] Upserted 700000/967871 rows; remaining 267871.
# [review] Upserted 701000/967871 rows; remaining 266871.
# [review] Upserted 702000/967871 rows; remaining 265871.
# [review] Upserted 703000/967871 rows; remaining 264871.
# [review] Upserted 704000/967871 rows; remaining 263871.
# [review] Upserted 705000/967871 rows; remaining 262871.
# [review] Upserted 706000/967871 rows; remaining 261871.
# [review] Upserted 707000/967871 rows; remaining 260871.
# [review] Upserted 708000/967871 rows; remaining 259871.
# [review] Upserted 709000/967871 rows; remaining 258871.
# [review] Upserted 710000/967871 rows; remaining 257871.
# [review] Upserted 711000/967871 rows; remaining 256871.
# [review] Upserted 712000/967871 rows; remaining 255871.
# [review] Upserted 713000/967871 rows; remaining 254871.
# [review] Upserted 714000/967871 rows; remaining 253871.
# [review] Upserted 715000/967871 rows; remaining 252871.
# [review] Upserted 716000/967871 rows; remaining 251871.
# [review] Upserted 717000/967871 rows; remaining 250871.
# [review] Upserted 718000/967871 rows; remaining 249871.
# [review] Upserted 719000/967871 rows; remaining 248871.
# [review] Upserted 720000/967871 rows; remaining 247871.
# [review] Upserted 721000/967871 rows; remaining 246871.
# [review] Upserted 722000/967871 rows; remaining 245871.
# [review] Upserted 723000/967871 rows; remaining 244871.
# [review] Upserted 724000/967871 rows; remaining 243871.
# [review] Upserted 725000/967871 rows; remaining 242871.
# [review] Upserted 726000/967871 rows; remaining 241871.
# [review] Upserted 727000/967871 rows; remaining 240871.
# [review] Upserted 728000/967871 rows; remaining 239871.
# [review] Upserted 729000/967871 rows; remaining 238871.
# [review] Upserted 730000/967871 rows; remaining 237871.
# [review] Upserted 731000/967871 rows; remaining 236871.
# [review] Upserted 732000/967871 rows; remaining 235871.
# [review] Upserted 733000/967871 rows; remaining 234871.
# [review] Upserted 734000/967871 rows; remaining 233871.
# [review] Upserted 735000/967871 rows; remaining 232871.
# [review] Upserted 736000/967871 rows; remaining 231871.
# [review] Upserted 737000/967871 rows; remaining 230871.
# [review] Upserted 738000/967871 rows; remaining 229871.
# [review] Upserted 739000/967871 rows; remaining 228871.
# [review] Upserted 740000/967871 rows; remaining 227871.
# [review] Upserted 741000/967871 rows; remaining 226871.
# [review] Upserted 742000/967871 rows; remaining 225871.
# [review] Upserted 743000/967871 rows; remaining 224871.
# [review] Upserted 744000/967871 rows; remaining 223871.
# [review] Upserted 745000/967871 rows; remaining 222871.
# [review] Upserted 746000/967871 rows; remaining 221871.
# [review] Upserted 747000/967871 rows; remaining 220871.
# [review] Upserted 748000/967871 rows; remaining 219871.
# [review] Upserted 749000/967871 rows; remaining 218871.
# [review] Upserted 750000/967871 rows; remaining 217871.
# [review] Upserted 751000/967871 rows; remaining 216871.
# [review] Upserted 752000/967871 rows; remaining 215871.
# [review] Upserted 753000/967871 rows; remaining 214871.
# [review] Upserted 754000/967871 rows; remaining 213871.
# [review] Upserted 755000/967871 rows; remaining 212871.
# [review] Upserted 756000/967871 rows; remaining 211871.
# [review] Upserted 757000/967871 rows; remaining 210871.
# [review] Upserted 758000/967871 rows; remaining 209871.
# [review] Upserted 759000/967871 rows; remaining 208871.
# [review] Upserted 760000/967871 rows; remaining 207871.
# [review] Upserted 761000/967871 rows; remaining 206871.
# [review] Upserted 762000/967871 rows; remaining 205871.
# [review] Upserted 763000/967871 rows; remaining 204871.
# [review] Upserted 764000/967871 rows; remaining 203871.
# [review] Upserted 765000/967871 rows; remaining 202871.
# [review] Upserted 766000/967871 rows; remaining 201871.
# [review] Upserted 767000/967871 rows; remaining 200871.
# [review] Upserted 768000/967871 rows; remaining 199871.
# [review] Upserted 769000/967871 rows; remaining 198871.
# [review] Upserted 770000/967871 rows; remaining 197871.
# [review] Upserted 771000/967871 rows; remaining 196871.
# [review] Upserted 772000/967871 rows; remaining 195871.
# [review] Upserted 773000/967871 rows; remaining 194871.
# [review] Upserted 774000/967871 rows; remaining 193871.
# [review] Upserted 775000/967871 rows; remaining 192871.
# [review] Upserted 776000/967871 rows; remaining 191871.
# [review] Upserted 777000/967871 rows; remaining 190871.
# [review] Upserted 778000/967871 rows; remaining 189871.
# [review] Upserted 779000/967871 rows; remaining 188871.
# [review] Upserted 780000/967871 rows; remaining 187871.
# [review] Upserted 781000/967871 rows; remaining 186871.
# [review] Upserted 782000/967871 rows; remaining 185871.
# [review] Upserted 783000/967871 rows; remaining 184871.
# [review] Upserted 784000/967871 rows; remaining 183871.
# [review] Upserted 785000/967871 rows; remaining 182871.
# [review] Upserted 786000/967871 rows; remaining 181871.
# [review] Upserted 787000/967871 rows; remaining 180871.
# [review] Upserted 788000/967871 rows; remaining 179871.
# [review] Upserted 789000/967871 rows; remaining 178871.
# [review] Upserted 790000/967871 rows; remaining 177871.
# [review] Upserted 791000/967871 rows; remaining 176871.
# [review] Upserted 792000/967871 rows; remaining 175871.
# [review] Upserted 793000/967871 rows; remaining 174871.
# [review] Upserted 794000/967871 rows; remaining 173871.
# [review] Upserted 795000/967871 rows; remaining 172871.
# [review] Upserted 796000/967871 rows; remaining 171871.
# [review] Upserted 797000/967871 rows; remaining 170871.
# [review] Upserted 798000/967871 rows; remaining 169871.
# [review] Upserted 799000/967871 rows; remaining 168871.
# [review] Upserted 800000/967871 rows; remaining 167871.
# [review] Upserted 801000/967871 rows; remaining 166871.
# [review] Upserted 802000/967871 rows; remaining 165871.
# [review] Upserted 803000/967871 rows; remaining 164871.
# [review] Upserted 804000/967871 rows; remaining 163871.
# [review] Upserted 805000/967871 rows; remaining 162871.
# [review] Upserted 806000/967871 rows; remaining 161871.
# [review] Upserted 807000/967871 rows; remaining 160871.
# [review] Upserted 808000/967871 rows; remaining 159871.
# [review] Upserted 809000/967871 rows; remaining 158871.
# [review] Upserted 810000/967871 rows; remaining 157871.
# [review] Upserted 811000/967871 rows; remaining 156871.
# [review] Upserted 812000/967871 rows; remaining 155871.
# [review] Upserted 813000/967871 rows; remaining 154871.
# [review] Upserted 814000/967871 rows; remaining 153871.
# [review] Upserted 815000/967871 rows; remaining 152871.
# [review] Upserted 816000/967871 rows; remaining 151871.
# [review] Upserted 817000/967871 rows; remaining 150871.
# [review] Upserted 818000/967871 rows; remaining 149871.
# [review] Upserted 819000/967871 rows; remaining 148871.
# [review] Upserted 820000/967871 rows; remaining 147871.
# [review] Upserted 821000/967871 rows; remaining 146871.
# [review] Upserted 822000/967871 rows; remaining 145871.
# [review] Upserted 823000/967871 rows; remaining 144871.
# [review] Upserted 824000/967871 rows; remaining 143871.
# [review] Upserted 825000/967871 rows; remaining 142871.
# [review] Upserted 826000/967871 rows; remaining 141871.
# [review] Upserted 827000/967871 rows; remaining 140871.
# [review] Upserted 828000/967871 rows; remaining 139871.
# [review] Upserted 829000/967871 rows; remaining 138871.
# [review] Upserted 830000/967871 rows; remaining 137871.
# [review] Upserted 831000/967871 rows; remaining 136871.
# [review] Upserted 832000/967871 rows; remaining 135871.
# [review] Upserted 833000/967871 rows; remaining 134871.
# [review] Upserted 834000/967871 rows; remaining 133871.
# [review] Upserted 835000/967871 rows; remaining 132871.
# [review] Upserted 836000/967871 rows; remaining 131871.
# [review] Upserted 837000/967871 rows; remaining 130871.
# [review] Upserted 838000/967871 rows; remaining 129871.
# [review] Upserted 839000/967871 rows; remaining 128871.
# [review] Upserted 840000/967871 rows; remaining 127871.
# [review] Upserted 841000/967871 rows; remaining 126871.
# [review] Upserted 842000/967871 rows; remaining 125871.
# [review] Upserted 843000/967871 rows; remaining 124871.
# [review] Upserted 844000/967871 rows; remaining 123871.
# [review] Upserted 845000/967871 rows; remaining 122871.
# [review] Upserted 846000/967871 rows; remaining 121871.
# [review] Upserted 847000/967871 rows; remaining 120871.
# [review] Upserted 848000/967871 rows; remaining 119871.
# [review] Upserted 849000/967871 rows; remaining 118871.
# [review] Upserted 850000/967871 rows; remaining 117871.
# [review] Upserted 851000/967871 rows; remaining 116871.
# [review] Upserted 852000/967871 rows; remaining 115871.
# [review] Upserted 853000/967871 rows; remaining 114871.
# [review] Upserted 854000/967871 rows; remaining 113871.
# [review] Upserted 855000/967871 rows; remaining 112871.
# [review] Upserted 856000/967871 rows; remaining 111871.
# [review] Upserted 857000/967871 rows; remaining 110871.
# [review] Upserted 858000/967871 rows; remaining 109871.
# [review] Upserted 859000/967871 rows; remaining 108871.
# [review] Upserted 860000/967871 rows; remaining 107871.
# [review] Upserted 861000/967871 rows; remaining 106871.
# [review] Upserted 862000/967871 rows; remaining 105871.
# [review] Upserted 863000/967871 rows; remaining 104871.
# [review] Upserted 864000/967871 rows; remaining 103871.
# [review] Upserted 865000/967871 rows; remaining 102871.
# [review] Upserted 866000/967871 rows; remaining 101871.
# [review] Upserted 867000/967871 rows; remaining 100871.
# [review] Upserted 868000/967871 rows; remaining 99871.
# [review] Upserted 869000/967871 rows; remaining 98871.
# [review] Upserted 870000/967871 rows; remaining 97871.
# [review] Upserted 871000/967871 rows; remaining 96871.
# [review] Upserted 872000/967871 rows; remaining 95871.
# [review] Upserted 873000/967871 rows; remaining 94871.
# [review] Upserted 874000/967871 rows; remaining 93871.
# [review] Upserted 875000/967871 rows; remaining 92871.
# [review] Upserted 876000/967871 rows; remaining 91871.
# [review] Upserted 877000/967871 rows; remaining 90871.
# [review] Upserted 878000/967871 rows; remaining 89871.
# [review] Upserted 879000/967871 rows; remaining 88871.
# [review] Upserted 880000/967871 rows; remaining 87871.
# [review] Upserted 881000/967871 rows; remaining 86871.
# [review] Upserted 882000/967871 rows; remaining 85871.
# [review] Upserted 883000/967871 rows; remaining 84871.
# [review] Upserted 884000/967871 rows; remaining 83871.
# [review] Upserted 885000/967871 rows; remaining 82871.
# [review] Upserted 886000/967871 rows; remaining 81871.
# [review] Upserted 887000/967871 rows; remaining 80871.
# [review] Upserted 888000/967871 rows; remaining 79871.
# [review] Upserted 889000/967871 rows; remaining 78871.
# [review] Upserted 890000/967871 rows; remaining 77871.
# [review] Upserted 891000/967871 rows; remaining 76871.
# [review] Upserted 892000/967871 rows; remaining 75871.
# [review] Upserted 893000/967871 rows; remaining 74871.
# [review] Upserted 894000/967871 rows; remaining 73871.
# [review] Upserted 895000/967871 rows; remaining 72871.
# [review] Upserted 896000/967871 rows; remaining 71871.
# [review] Upserted 897000/967871 rows; remaining 70871.
# [review] Upserted 898000/967871 rows; remaining 69871.
# [review] Upserted 899000/967871 rows; remaining 68871.
# [review] Upserted 900000/967871 rows; remaining 67871.
# [review] Upserted 901000/967871 rows; remaining 66871.
# [review] Upserted 902000/967871 rows; remaining 65871.
# [review] Upserted 903000/967871 rows; remaining 64871.
# [review] Upserted 904000/967871 rows; remaining 63871.
# [review] Upserted 905000/967871 rows; remaining 62871.
# [review] Upserted 906000/967871 rows; remaining 61871.
# [review] Upserted 907000/967871 rows; remaining 60871.
# [review] Upserted 908000/967871 rows; remaining 59871.
# [review] Upserted 909000/967871 rows; remaining 58871.
# [review] Upserted 910000/967871 rows; remaining 57871.
# [review] Upserted 911000/967871 rows; remaining 56871.
# [review] Upserted 912000/967871 rows; remaining 55871.
# [review] Upserted 913000/967871 rows; remaining 54871.
# [review] Upserted 914000/967871 rows; remaining 53871.
# [review] Upserted 915000/967871 rows; remaining 52871.
# [review] Upserted 916000/967871 rows; remaining 51871.
# [review] Upserted 917000/967871 rows; remaining 50871.
# [review] Upserted 918000/967871 rows; remaining 49871.
# [review] Upserted 919000/967871 rows; remaining 48871.
# [review] Upserted 920000/967871 rows; remaining 47871.
# [review] Upserted 921000/967871 rows; remaining 46871.
# [review] Upserted 922000/967871 rows; remaining 45871.
# [review] Upserted 923000/967871 rows; remaining 44871.
# [review] Upserted 924000/967871 rows; remaining 43871.
# [review] Upserted 925000/967871 rows; remaining 42871.
# [review] Upserted 926000/967871 rows; remaining 41871.
# [review] Upserted 927000/967871 rows; remaining 40871.
# [review] Upserted 928000/967871 rows; remaining 39871.
# [review] Upserted 929000/967871 rows; remaining 38871.
# [review] Upserted 930000/967871 rows; remaining 37871.
# [review] Upserted 931000/967871 rows; remaining 36871.
# [review] Upserted 932000/967871 rows; remaining 35871.
# [review] Upserted 933000/967871 rows; remaining 34871.
# [review] Upserted 934000/967871 rows; remaining 33871.
# [review] Upserted 935000/967871 rows; remaining 32871.
# [review] Upserted 936000/967871 rows; remaining 31871.
# [review] Upserted 937000/967871 rows; remaining 30871.
# [review] Upserted 938000/967871 rows; remaining 29871.
# [review] Upserted 939000/967871 rows; remaining 28871.
# [review] Upserted 940000/967871 rows; remaining 27871.
# [review] Upserted 941000/967871 rows; remaining 26871.
# [review] Upserted 942000/967871 rows; remaining 25871.
# [review] Upserted 943000/967871 rows; remaining 24871.
# [review] Upserted 944000/967871 rows; remaining 23871.
# [review] Upserted 945000/967871 rows; remaining 22871.
# [review] Upserted 946000/967871 rows; remaining 21871.
# [review] Upserted 947000/967871 rows; remaining 20871.
# [review] Upserted 948000/967871 rows; remaining 19871.
# [review] Upserted 949000/967871 rows; remaining 18871.
# [review] Upserted 950000/967871 rows; remaining 17871.
# [review] Upserted 951000/967871 rows; remaining 16871.
# [review] Upserted 952000/967871 rows; remaining 15871.
# [review] Upserted 953000/967871 rows; remaining 14871.
# [review] Upserted 954000/967871 rows; remaining 13871.
# [review] Upserted 955000/967871 rows; remaining 12871.
# [review] Upserted 956000/967871 rows; remaining 11871.
# [review] Upserted 957000/967871 rows; remaining 10871.
# [review] Upserted 958000/967871 rows; remaining 9871.
# [review] Upserted 959000/967871 rows; remaining 8871.
# [review] Upserted 960000/967871 rows; remaining 7871.
# [review] Upserted 961000/967871 rows; remaining 6871.
# [review] Upserted 962000/967871 rows; remaining 5871.
# [review] Upserted 963000/967871 rows; remaining 4871.
# [review] Upserted 964000/967871 rows; remaining 3871.
# [review] Upserted 965000/967871 rows; remaining 2871.
# [review] Upserted 966000/967871 rows; remaining 1871.
# [review] Upserted 967000/967871 rows; remaining 871.
# [review] Upserted 967871/967871 rows; remaining 0.
# Philadelphia, PA businesses: 14,575
# Philadelphia, PA attributes: 127,463
# Philadelphia, PA hours: 74,168
# Philadelphia, PA checkins: 12,899
# Philadelphia, PA reviews: 967,871
